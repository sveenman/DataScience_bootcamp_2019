# %% [markdown]
# For instructions how to make the R kernel available to Jupyter see [here](https://irkernel.github.io/installation/)

# %%
library(ggplot2)
# Out:
# Warning message:
# : package ‘ggplot2’ was built under R version 3.2.3

# %%
mtcars$am<-as.factor(mtcars$am)

p <- qplot(hp, mpg, data=mtcars, shape=am, color=am,
           facets=gear~cyl, main="Scatterplots of MPG vs. Horsepower",
           xlab="Horsepower", ylab="Miles per Gallon")

# Large brown bold italics labels
# and legend placed at top of plot
p + theme(axis.title=element_text(face="bold.italic",
                                  size="12", color="brown"), legend.position="top")
# Out:
# plot without title
